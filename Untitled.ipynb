# %%
import os
os.environ["IMAGEIO_FFMPEG_EXE"] = "/usr/bin/ffmpeg"
from moviepy.editor import *

# %%
clip = VideoFileClip("./static/uploads/Sample_Video_2.5_Min.mp4")
clip = clip.subclip(t_start=1, t_end=5)

# %%
clip.ipython_display(width=500, maxduration=1000000)
# Out:
# t:  28%|███████████▌                              | 33/120 [00:00<00:00, 327.74it/s, now=None]
# Moviepy - Building video __temp__.mp4.
# MoviePy - Writing audio in __temp__TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='500'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
clip.close()

# %%
print(os.name)
# Out:
# posix
